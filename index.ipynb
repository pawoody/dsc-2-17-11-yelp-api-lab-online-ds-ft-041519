# %% [markdown]
# # Yelp API - Lab
#
# The previously deployed lab on working around building a GIS with Yelp API and Folium can be found [here](https://github.com/learn-co-curriculum/dsc-2-15-10-yelp-api-gis-lab/tree/a56358c2d0c2daf569a5f50937c4c27463aadb1a) (not relevant for new students).
#
#
# ## Introduction
#
# Now that we've seen how the Yelp API works, and some basic Folium visualizations its time to put those skills to work in order to create a working map! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API!
#
# ## Objectives
#
# You will be able to:
# * Create HTTP requests to get data from Yelp API
# * Parse HTTP responses and perform data analysis on the data returned
# * Perform pagination to retrieve troves of data!
# * Create a simple geographical system on to view information about selected businesses, at a given location.

# %% [markdown]
# ## Problem Introduction
#
# You've now worked with some API calls, but we have yet to see how to retrieve a more complete dataset in a programmatic manner. Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the API limits. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a maximum of 50 results per request and defaults to 20. Furthermore, any search will be limited to a total of 1000 results. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retriving 50 at a time. Processes such as these are often refered to as pagination.
#
# In this lab, you will define a search and then paginate over the results to retrieve all of the results. You'll then parse these responses as a DataFrame (for further exploration) and create a map using Folium to visualize the results geographically.

# %%
import requests

# %%
client_id = 'oDAa3Ow9MzHoxT-E8lRpjw'
api_key = 'uVg8lCY5gaJUz_K4cj5-wRwWodOs5kkfDPm5U_6pgf7CKQgaS_Z8xIW3W8fDS-NnhvZ9w0LxXl9H5LZfHrywHSEIXlaxZyG00qTl3bgUW7R4oDFBTMQyNK_1DzT5XHYx'

# %% [markdown]
# ## Part I - Make the Initial Request
#
# Start by making an initial request to the Yelp API. Your search must include at least 2 parameters: **term** and **location**. For example, you might search for pizza restaurants in NYC. The term and location is up to you, but make the request below.

# %%
term = 'Korean'
location = 'San Francisco'
SEARCH_LIMIT = 10

url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }

response = requests.get(url, headers=headers, params=url_params)
print(response)
print(type(response.text))
print(response.text[:1000])
# Out:
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "dY0Mc_PHH6nLENvWmVtwxQ", "alias": "daeho-kalbijjim-and-beef-soup-san-francisco-9", "name": "Daeho Kalbijjim & Beef Soup", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/NjLR02YB4810aC8QDCDTXQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/daeho-kalbijjim-and-beef-soup-san-francisco-9?adjust_creative=oDAa3Ow9MzHoxT-E8lRpjw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oDAa3Ow9MzHoxT-E8lRpjw", "review_count": 243, "categories": [{"alias": "korean", "title": "Korean"}, {"alias": "soup", "title": "Soup"}, {"alias": "noodles", "title": "Noodles"}], "rating": 4.5, "coordinates": {"latitude": 37.78601, "longitude": -122.42858}, "transactions": [], "price": "$$", "location": {"address1": "1620 Post St", "address2": "", "address3": null, "city": "San Francisco", "zip_code": "94115", "country": "US", "state": "CA", "display_address": ["1620 Post St", "San Francisco, CA 94115"]}, "phone": "+14155631388", "display_phone": "(415)

# %% [markdown]
# ## Pagination
#
# Now that you have an initial response, you can examine the contents of the json container. For example, you might start with ```response.josn().keys()```. Here, you'll see a key for `'total'`, which tells you the full number of matching results given your query parameters. Write a loop (or ideally a function) which then makes successive API calls using the offset parameter to retrieve all of the results (or 5000 for a particularly large result set) for the original query. As you do this, be mindful of how you store the data. Your final goal will be to reformat the data concerning the businesses themselves into a pandas DataFrame from the json objects.
#
# **Note: be mindful of the API rate limits. You can only make 5000 requests per day, and are also can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use time.sleep(n) to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.**

# %%
# Your code here; use a function or loop to retrieve all the results from your original request
response.json().keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
for key in response.json().keys():
    print(key)
    value = response.json()[key] 
    print((value)) 
    print('\n\n')
# Out:
# businesses
# [{'id': 'dY0Mc_PHH6nLENvWmVtwxQ', 'alias': 'daeho-kalbijjim-and-beef-soup-san-francisco-9', 'name': 'Daeho Kalbijjim & Beef Soup', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NjLR02YB4810aC8QDCDTXQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/daeho-kalbijjim-and-beef-soup-san-francisco-9?adjust_creative=oDAa3Ow9MzHoxT-E8lRpjw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oDAa3Ow9MzHoxT-E8lRpjw', 'review_count': 243, 'categories': [{'alias': 'korean', 'title': 'Korean'}, {'alias': 'soup', 'title': 'Soup'}, {'alias': 'noodles', 'title': 'Noodles'}], 'rating': 4.5, 'coordinates': {'latitude': 37.78601, 'longitude': -122.42858}, 'transactions': [], 'price': '$$', 'location': {'address1': '1620 Post St', 'address2': '', 'address3': None, 'city': 'San Francisco', 'zip_code': '94115', 'country': 'US', 'state': 'CA', 'display_address': ['1620 Post St', 'San Francisco, CA 94115']}, 'phone': '+14155631388', 'display_phone': '(415) 563-1388', 'distance': 2863.096983817991}, {'id': 'eBxkmr-hJ2KgpZQzEO3ArQ', 'alias': 'han-il-kwan-san-francisco', 'name': 'Han Il Kwan', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4oWPvCLkLh8P1nWCo4qlYg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/han-il-kwan-san-francisco?adjust_creative=oDAa3Ow9MzHoxT-E8lRpjw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oDAa3Ow9MzHoxT-E8lRpjw', 'review_count': 1538, 'categories': [{'alias': 'korean', 'title': 'Korean'}], 'rating': 4.0, 'coordinates': {'latitude': 37.77675, 'longitude': -122.4783}, 'transactions': [], 'price': '$$', 'location': {'address1': '1802 Balboa St', 'address2': '', 'address3': '', 'city': 'San Francisco', 'zip_code': '94121', 'country': 'US', 'state': 'CA', 'display_address': ['1802 Balboa St', 'San Francisco, CA 94121']}, 'phone': '+14157524447', 'display_phone': '(415) 752-4447', 'distance': 4083.5026815024607}, {'id': 'd74oNV0yHMfZPVoYy9Ha8A', 'alias': 'jang-soo-bbq-san-francisco', 'name': 'Jang Soo BBQ', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HHdKsjKTAZHW2RBI0VETaA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/jang-soo-bbq-san-francisco?adjust_creative=oDAa3Ow9MzHoxT-E8lRpjw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oDAa3Ow9MzHoxT-E8lRpjw', 'review_count': 525, 'categories': [{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'korean', 'title': 'Korean'}, {'alias': 'soup', 'title': 'Soup'}], 'rating': 4.0, 'coordinates': {'latitude': 37.780196, 'longitude': -122.487262}, 'transactions': ['delivery', 'restaurant_reservation', 'pickup'], 'price': '$$', 'location': {'address1': '6314 Geary Blvd', 'address2': '', 'address3': '', 'city': 'San Francisco', 'zip_code': '94121', 'country': 'US', 'state': 'CA', 'display_address': ['6314 Geary Blvd', 'San Francisco, CA 94121']}, 'phone': '+14152218282', 'display_phone': '(415) 221-8282', 'distance': 4955.0937242671125}, {'id': 'tr15WgMHIC_W2gqBpuk3-A', 'alias': 'manna-san-francisco', 'name': 'Manna', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Xlwqdh2X0l5giKL9cUYykA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/manna-san-francisco?adjust_creative=oDAa3Ow9MzHoxT-E8lRpjw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oDAa3Ow9MzHoxT-E8lRpjw', 'review_count': 997, 'categories': [{'alias': 'korean', 'title': 'Korean'}], 'rating': 4.0, 'coordinates': {'latitude': 37.76384, 'longitude': -122.46708}, 'transactions': [], 'price': '$$', 'location': {'address1': '845 Irving St', 'address2': '', 'address3': '', 'city': 'San Francisco', 'zip_code': '94122', 'country': 'US', 'state': 'CA', 'display_address': ['845 Irving St', 'San Francisco, CA 94122']}, 'phone': '+14156655969', 'display_phone': '(415) 665-5969', 'distance': 2726.245198144492}, {'id': 'i09UMzccKgyLwGYKDVP28w', 'alias': 'surisan-san-francisco', 'name': 'Surisan', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CQjUMLXrjMLPOhRgDmGyGw/o.jpg', 'is_cl ...
#
#
#
# total
# 770
#
#
#
# region
# {'center': {'longitude': -122.43644714355469, 'latitude': 37.76089938976322}}

# %%
response.json()['businesses'][::]
# Out:
# [{'id': 'dY0Mc_PHH6nLENvWmVtwxQ',
#   'alias': 'daeho-kalbijjim-and-beef-soup-san-francisco-9',
#   'name': 'Daeho Kalbijjim & Beef Soup',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NjLR02YB4810aC8QDCDTXQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/daeho-kalbijjim-and-beef-soup-san-francisco-9?adjust_creative=oDAa3Ow9MzHoxT-E8lRpjw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oDAa3Ow9MzHoxT-E8lRpjw',
#   'review_count': 243,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'soup', 'title': 'Soup'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.78601, 'longitude': -122.42858},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1620 Post St',
#    'address2': '',
#    'address3': None,
#    'city': 'San Francisco',
#    'zip_code': '94115',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1620 Post St', 'San Francisco, CA 94115']},
#   'phone': '+14155631388',
#   'display_phone': '(415) 563-1388',
#   'distance': 2863.096983817991},
#  {'id': 'eBxkmr-hJ2KgpZQzEO3ArQ',
#   'alias': 'han-il-kwan-san-francisco',
#   'name': 'Han Il Kwan',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4oWPvCLkLh8P1nWCo4qlYg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/han-il-kwan-san-francisco?adjust_creative=oDAa3Ow9MzHoxT-E8lRpjw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oDAa3Ow9MzHoxT-E8lRpjw',
#   'review_count': 1538,
#   'categories': [{'alias': 'korean', 'title': 'Korean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.77675, 'longitude': -122.4783},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1802 Balboa St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94121',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1802 Balboa St', 'San Francisco, CA 94121']},
#   'phone': '+14157524447',
#   'display_phone': '(415) 752-4447',
#   'distance': 4083.5026815024607},
#  {'id': 'd74oNV0yHMfZPVoYy9Ha8A',
#   'alias': 'jang-soo-bbq-san-francisco',
#   'name': 'Jang Soo BBQ',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HHdKsjKTAZHW2RBI0VETaA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jang-soo-bbq-san-francisco?adjust_creative=oDAa3Ow9MzHoxT-E8lRpjw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oDAa3Ow9MzHoxT-E8lRpjw',
#   'review_count': 525,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.780196, 'longitude': -122.487262},
#   'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '6314 Geary Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94121',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['6314 Geary Blvd', 'San Francisco, CA 94121']},
#   'phone': '+14152218282',
#   'display_phone': '(415) 221-8282',
#   'distance': 4955.0937242671125},
#  {'id': 'tr15WgMHIC_W2gqBpuk3-A',
#   'alias': 'manna-san-francisco',
#   'name': 'Manna',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Xlwqdh2X0l5giKL9cUYykA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/manna-san-francisco?adjust_creative=oDAa3Ow9MzHoxT-E8lRpjw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oDAa3Ow9MzHoxT-E8lRpjw',
#   'review_count': 997,
#   'categories': [{'alias': 'korean', 'title': 'Korean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.76384, 'longitude': -122.46708},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '845 Irving St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94122',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['845 Irving St', 'San Francisco, CA 94122']},
#   'phone': '+14156655969',
#   'display_phone': '(415) 665-5969',
#   'distance': 2726.245198144492},
#  {'id': 'i09UMzccKgyLwGYKDVP28w',
#   'alias': 'surisan-san-francisco',
#   'name': 'Surisan',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CQjUMLXrjMLPOhRgDmGyGw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/surisan-san-francisco?adjust_creative=oDAa3Ow9MzHoxT-E8lRpjw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oDAa3Ow9MzHoxT-E8lRpjw',
#   'review_count': 1410,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.80678, 'longitude': -122.41756},
#   'transactions': ['restaurant_reservation', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '505 Beach St',
#    'address2': '',
#    'address3': None,
#    'city': 'San Francisco',
#    'zip_code': '94133',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['505 Beach St', 'San Francisco, CA 94133']},
#   'phone': '+14157718449',
#   'display_phone': '(415) 771-8449',
#   'distance': 5366.476620396218},
#  {'id': '8oAsGZNNLvIW3CvLcFUPMw',
#   'alias': 'muguboka-restaurant-san-francisco',
#   'name': 'Muguboka Restaurant',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hdzHKxZdW0Ac4w2V45fb8g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/muguboka-restaurant-san-francisco?adjust_creative=oDAa3Ow9MzHoxT-E8lRpjw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oDAa3Ow9MzHoxT-E8lRpjw',
#   'review_count': 747,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.77713, 'longitude': -122.46317},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '401 Balboa St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94118',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['401 Balboa St', 'San Francisco, CA 94118']},
#   'phone': '+14156686007',
#   'display_phone': '(415) 668-6007',
#   'distance': 2958.2773662434656},
#  {'id': 'KhG-jWIr7-TJj3isz3ZIFQ',
#   'alias': 'my-tofu-house-san-francisco',
#   'name': 'My Tofu House',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/S7JMyrYv3dsBmAqPtbj_qA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/my-tofu-house-san-francisco?adjust_creative=oDAa3Ow9MzHoxT-E8lRpjw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oDAa3Ow9MzHoxT-E8lRpjw',
#   'review_count': 1626,
#   'categories': [{'alias': 'korean', 'title': 'Korean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7806563, 'longitude': -122.4691286},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '4627 Geary Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94118',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['4627 Geary Blvd', 'San Francisco, CA 94118']},
#   'phone': '+14157501818',
#   'display_phone': '(415) 750-1818',
#   'distance': 3616.331071494143},
#  {'id': 'nJziHiIt86OGqKQQFHd9jg',
#   'alias': 'jin-mi-korean-cuisine-san-francisco',
#   'name': 'Jin Mi Korean Cuisine',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Xbi2Xy0T6aTDPq51C2QZ2A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jin-mi-korean-cuisine-san-francisco?adjust_creative=oDAa3Ow9MzHoxT-E8lRpjw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oDAa3Ow9MzHoxT-E8lRpjw',
#   'review_count': 434,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'soup', 'title': 'Soup'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.78162, 'longitude': -122.41682},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '366 Golden Gate Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94102',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['366 Golden Gate Ave', 'San Francisco, CA 94102']},
#   'phone': '+14158345007',
#   'display_phone': '(415) 834-5007',
#   'distance': 2904.2345798919227},
#  {'id': 'KA-P3d2NcbJy5SQN-vCzPA',
#   'alias': 'aria-korean-street-food-san-francisco',
#   'name': 'Aria Korean Street Food',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_ULoxzAds4VhjhOE4kiRiQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/aria-korean-street-food-san-francisco?adjust_creative=oDAa3Ow9MzHoxT-E8lRpjw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oDAa3Ow9MzHoxT-E8lRpjw',
#   'review_count': 594,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#    {'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.78655, 'longitude': -122.41795},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '932 Larkin St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94109',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['932 Larkin St', 'San Francisco, CA 94109']},
#   'phone': '+14152926914',
#   'display_phone': '(415) 292-6914',
#   'distance': 3285.2839097170254},
#  {'id': '2E9O-p-lp587aOMnpLepkQ',
#   'alias': 'jijime-san-francisco-8',
#   'name': 'JIJIME',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4oowWGAzNmFLEx4vDtBAlg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jijime-san-francisco-8?adjust_creative=oDAa3Ow9MzHoxT-E8lRpjw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oDAa3Ow9MzHoxT-E8lRpjw',
#   'review_count': 232,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.7806549278456,
#    'longitude': -122.478949574806},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '5524 Geary Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'San Francisco',
#    'zip_code': '94121',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['5524 Geary Blvd', 'San Francisco, CA 94121']},
#   'phone': '+14152215353',
#   'display_phone': '(415) 221-5353',
#   'distance': 4333.781775165417}]

# %% [markdown]
# ## Exploratory Analysis
#
# Take the restaurants from the previous question and do an intial exploratory analysis. At minimum, this should include looking at the distribution of features such as price, rating and number of reviews as well as the relations between these dimensions.

# %%
import pandas as pd

df = pd.DataFrame.from_dict(response.json()['businesses'])
print(len(df)) 
print(df.columns)
df.head(10)
# Out:
# 10
# Index(['alias', 'categories', 'coordinates', 'display_phone', 'distance', 'id',
#        'image_url', 'is_closed', 'location', 'name', 'phone', 'price',
#        'rating', 'review_count', 'transactions', 'url'],
#       dtype='object')
#                                            alias  \
# 0  daeho-kalbijjim-and-beef-soup-san-francisco-9
# 1                      han-il-kwan-san-francisco
# 2                     jang-soo-bbq-san-francisco
# 3                            manna-san-francisco
# 4                          surisan-san-francisco
# 5              muguboka-restaurant-san-francisco
# 6                    my-tofu-house-san-francisco
# 7            jin-mi-korean-cuisine-san-francisco
# 8          aria-korean-street-food-san-francisco
# 9                         jijime-san-francisco-8
#
#                                           categories  \
# 0  [{'alias': 'korean', 'title': 'Korean'}, {'ali...
# 1           [{'alias': 'korean', 'title': 'Korean'}]
# 2  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...
# 3           [{'alias': 'korean', 'title': 'Korean'}]
# 4  [{'alias': 'korean', 'title': 'Korean'}, {'ali...
# 5  [{'alias': 'korean', 'title': 'Korean'}, {'ali...
# 6           [{'alias': 'korean', 'title': 'Korean'}]
# 7  [{'alias': 'korean', 'title': 'Korean'}, {'ali...
# 8  [{'alias': 'korean', 'title': 'Korean'}, {'ali...
# 9  [{'alias': 'korean', 'title': 'Korean'}, {'ali...
#
#                                          coordinates   display_phone  \
# 0    {'latitude': 37.78601, 'longitude': -122.42858}  (415) 563-1388
# 1     {'latitude': 37.77675, 'longitude': -122.4783}  (415) 752-4447
# 2  {'latitude': 37.780196, 'longitude': -122.487262}  (415) 221-8282
# 3    {'latitude': 37.76384, 'longitude': -122.46708}  (415) 665-5969
# 4    {'latitude': 37.80678, 'longitude': -122.41756}  (415) 771-8449
# 5    {'latitude': 37.77713, 'longitude': -122.46317}  (415) 668-6007
# 6  {'latitude': 37.7806563, 'longitude': -122.469...  (415) 750-1818
# 7    {'latitude': 37.78162, 'longitude': -122.41682}  (415) 834-5007
# 8    {'latitude': 37.78655, 'longitude': -122.41795}  (415) 292-6914
# 9  {'latitude': 37.7806549278456, 'longitude': -1...  (415) 221-5353
#
#       distance                      id  \
# 0  2863.096984  dY0Mc_PHH6nLENvWmVtwxQ
# 1  4083.502682  eBxkmr-hJ2KgpZQzEO3ArQ
# 2  4955.093724  d74oNV0yHMfZPVoYy9Ha8A
# 3  2726.245198  tr15WgMHIC_W2gqBpuk3-A
# 4  5366.476620  i09UMzccKgyLwGYKDVP28w
# 5  2958.277366  8oAsGZNNLvIW3CvLcFUPMw
# 6  3616.331071  KhG-jWIr7-TJj3isz3ZIFQ
# 7  2904.234580  nJziHiIt86OGqKQQFHd9jg
# 8  3285.283910  KA-P3d2NcbJy5SQN-vCzPA
# 9  4333.781775  2E9O-p-lp587aOMnpLepkQ
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/NjLR02...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/4oWPvC...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/HHdKsj...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/Xlwqdh...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/CQjUML...      False
# 5  https://s3-media4.fl.yelpcdn.com/bphoto/hdzHKx...      False
# 6  https://s3-media1.fl.yelpcdn.com/bphoto/S7JMyr...      False
# 7  https://s3-media4.fl.yelpcdn.com/bphoto/Xbi2Xy...      False
# 8  https://s3-media1.fl.yelpcdn.com/bphoto/_ULoxz...      False
# 9  https://s3-media2.fl.yelpcdn.com/bphoto/4oowWG...      False
#
#                                             location  \
# 0  {'address1': '1620 Post St', 'address2': '', '...
# 1  {'address1': '1802 Balboa St', 'address2': '',...
# 2  {'address1': '6314 Geary Blvd', 'address2': ''...
# 3  {'address1': '845 Irving St', 'address2': '', ...
# 4  {'address1': '505 Beach St', 'address2': '', '...
# 5  {'address1': '401 Balboa St', 'address2': '', ...
# 6  {'address1': '4627 Geary Blvd', 'address2': ''...
# 7  {'address1': '366 Golden Gate Ave', 'address2'...
# 8  {'address1': '932 Larkin St', 'address2': '', ...
# 9  {'address1': '5524 Geary Blvd', 'address2': ''...
#
#                           name         phone price  rating  review_count  \
# 0  Daeho Kalbijjim & Beef Soup  +14155631388    $$     4.5           243
# 1                  Han Il Kwan  +14157524447    $$     4.0          1538
# 2                 Jang Soo BBQ  +14152218282    $$     4.0           525
# 3                        Manna  +14156655969    $$     4.0           997
# 4                      Surisan  +14157718449    $$     4.5          1410
# 5          Muguboka Restaurant  +14156686007    $$     4.0           747
# 6                My Tofu House  +14157501818    $$     4.0          1626
# 7        Jin Mi Korean Cuisine  +14158345007    $$     4.0           434
# 8      Aria Korean Street Food  +14152926914    $$     4.0           594
# 9                       JIJIME  +14152215353    $$     4.5           232
#
#                                  transactions  \
# 0                                          []
# 1                                          []
# 2  [delivery, restaurant_reservation, pickup]
# 3                                          []
# 4            [restaurant_reservation, pickup]
# 5                                          []
# 6                                          []
# 7                          [delivery, pickup]
# 8                          [delivery, pickup]
# 9                          [delivery, pickup]
#
#                                                  url
# 0  https://www.yelp.com/biz/daeho-kalbijjim-and-b...
# 1  https://www.yelp.com/biz/han-il-kwan-san-franc...
# 2  https://www.yelp.com/biz/jang-soo-bbq-san-fran...
# 3  https://www.yelp.com/biz/manna-san-francisco?a...
# 4  https://www.yelp.com/biz/surisan-san-francisco...
# 5  https://www.yelp.com/biz/muguboka-restaurant-s...
# 6  https://www.yelp.com/biz/my-tofu-house-san-fra...
# 7  https://www.yelp.com/biz/jin-mi-korean-cuisine...
# 8  https://www.yelp.com/biz/aria-korean-street-fo...
# 9  https://www.yelp.com/biz/jijime-san-francisco-...

# %%
import matplotlib as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
"""
sns.pairplot(data, hue=None, hue_order=None, palette=None, vars=None, x_vars=None, y_vars=None, kind='scatter', diag_kind='auto', markers=None, height=2.5, aspect=1, dropna=True, plot_kws=None, diag_kws=None, grid_kws=None, size=None)

# %%
sns.pairplot?

# %%
df.price.unique()
# Out:
# array(['$$'], dtype=object)

# %%
df.price.map?

# %%
df.price = df.price.fillna(value=0)
price_convert = {'$': 1, '$$': 2, '$$$': 3, '$$$$': 4}
df.price = df.price.map(price_convert)

# %%
df.price.unique()
# Out:
# array([2])

# %%
df.head(10)
# Out:
#                                            alias  \
# 0  daeho-kalbijjim-and-beef-soup-san-francisco-9
# 1                      han-il-kwan-san-francisco
# 2                     jang-soo-bbq-san-francisco
# 3                            manna-san-francisco
# 4                          surisan-san-francisco
# 5              muguboka-restaurant-san-francisco
# 6                    my-tofu-house-san-francisco
# 7            jin-mi-korean-cuisine-san-francisco
# 8          aria-korean-street-food-san-francisco
# 9                         jijime-san-francisco-8
#
#                                           categories  \
# 0  [{'alias': 'korean', 'title': 'Korean'}, {'ali...
# 1           [{'alias': 'korean', 'title': 'Korean'}]
# 2  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...
# 3           [{'alias': 'korean', 'title': 'Korean'}]
# 4  [{'alias': 'korean', 'title': 'Korean'}, {'ali...
# 5  [{'alias': 'korean', 'title': 'Korean'}, {'ali...
# 6           [{'alias': 'korean', 'title': 'Korean'}]
# 7  [{'alias': 'korean', 'title': 'Korean'}, {'ali...
# 8  [{'alias': 'korean', 'title': 'Korean'}, {'ali...
# 9  [{'alias': 'korean', 'title': 'Korean'}, {'ali...
#
#                                          coordinates   display_phone  \
# 0    {'latitude': 37.78601, 'longitude': -122.42858}  (415) 563-1388
# 1     {'latitude': 37.77675, 'longitude': -122.4783}  (415) 752-4447
# 2  {'latitude': 37.780196, 'longitude': -122.487262}  (415) 221-8282
# 3    {'latitude': 37.76384, 'longitude': -122.46708}  (415) 665-5969
# 4    {'latitude': 37.80678, 'longitude': -122.41756}  (415) 771-8449
# 5    {'latitude': 37.77713, 'longitude': -122.46317}  (415) 668-6007
# 6  {'latitude': 37.7806563, 'longitude': -122.469...  (415) 750-1818
# 7    {'latitude': 37.78162, 'longitude': -122.41682}  (415) 834-5007
# 8    {'latitude': 37.78655, 'longitude': -122.41795}  (415) 292-6914
# 9  {'latitude': 37.7806549278456, 'longitude': -1...  (415) 221-5353
#
#       distance                      id  \
# 0  2863.096984  dY0Mc_PHH6nLENvWmVtwxQ
# 1  4083.502682  eBxkmr-hJ2KgpZQzEO3ArQ
# 2  4955.093724  d74oNV0yHMfZPVoYy9Ha8A
# 3  2726.245198  tr15WgMHIC_W2gqBpuk3-A
# 4  5366.476620  i09UMzccKgyLwGYKDVP28w
# 5  2958.277366  8oAsGZNNLvIW3CvLcFUPMw
# 6  3616.331071  KhG-jWIr7-TJj3isz3ZIFQ
# 7  2904.234580  nJziHiIt86OGqKQQFHd9jg
# 8  3285.283910  KA-P3d2NcbJy5SQN-vCzPA
# 9  4333.781775  2E9O-p-lp587aOMnpLepkQ
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/NjLR02...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/4oWPvC...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/HHdKsj...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/Xlwqdh...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/CQjUML...      False
# 5  https://s3-media4.fl.yelpcdn.com/bphoto/hdzHKx...      False
# 6  https://s3-media1.fl.yelpcdn.com/bphoto/S7JMyr...      False
# 7  https://s3-media4.fl.yelpcdn.com/bphoto/Xbi2Xy...      False
# 8  https://s3-media1.fl.yelpcdn.com/bphoto/_ULoxz...      False
# 9  https://s3-media2.fl.yelpcdn.com/bphoto/4oowWG...      False
#
#                                             location  \
# 0  {'address1': '1620 Post St', 'address2': '', '...
# 1  {'address1': '1802 Balboa St', 'address2': '',...
# 2  {'address1': '6314 Geary Blvd', 'address2': ''...
# 3  {'address1': '845 Irving St', 'address2': '', ...
# 4  {'address1': '505 Beach St', 'address2': '', '...
# 5  {'address1': '401 Balboa St', 'address2': '', ...
# 6  {'address1': '4627 Geary Blvd', 'address2': ''...
# 7  {'address1': '366 Golden Gate Ave', 'address2'...
# 8  {'address1': '932 Larkin St', 'address2': '', ...
# 9  {'address1': '5524 Geary Blvd', 'address2': ''...
#
#                           name         phone  price  rating  review_count  \
# 0  Daeho Kalbijjim & Beef Soup  +14155631388      2     4.5           243
# 1                  Han Il Kwan  +14157524447      2     4.0          1538
# 2                 Jang Soo BBQ  +14152218282      2     4.0           525
# 3                        Manna  +14156655969      2     4.0           997
# 4                      Surisan  +14157718449      2     4.5          1410
# 5          Muguboka Restaurant  +14156686007      2     4.0           747
# 6                My Tofu House  +14157501818      2     4.0          1626
# 7        Jin Mi Korean Cuisine  +14158345007      2     4.0           434
# 8      Aria Korean Street Food  +14152926914      2     4.0           594
# 9                       JIJIME  +14152215353      2     4.5           232
#
#                                  transactions  \
# 0                                          []
# 1                                          []
# 2  [delivery, restaurant_reservation, pickup]
# 3                                          []
# 4            [restaurant_reservation, pickup]
# 5                                          []
# 6                                          []
# 7                          [delivery, pickup]
# 8                          [delivery, pickup]
# 9                          [delivery, pickup]
#
#                                                  url
# 0  https://www.yelp.com/biz/daeho-kalbijjim-and-b...
# 1  https://www.yelp.com/biz/han-il-kwan-san-franc...
# 2  https://www.yelp.com/biz/jang-soo-bbq-san-fran...
# 3  https://www.yelp.com/biz/manna-san-francisco?a...
# 4  https://www.yelp.com/biz/surisan-san-francisco...
# 5  https://www.yelp.com/biz/muguboka-restaurant-s...
# 6  https://www.yelp.com/biz/my-tofu-house-san-fra...
# 7  https://www.yelp.com/biz/jin-mi-korean-cuisine...
# 8  https://www.yelp.com/biz/aria-korean-street-fo...
# 9  https://www.yelp.com/biz/jijime-san-francisco-...

# %%
sns.pairplot(data=df, kind='scatter', vars=('price', 'review_count', 'rating'))

# %% [markdown]
# ## Mapping
#
# Look at the initial Yelp example and try and make a map using Folium of the restaurants you retrieved. Be sure to also add popups to the markers giving some basic information such as name, rating and price.

# %%
import folium

# %%
lat = 37.8
long = -122.4

base_map = folium.Map([lat, long], zoom_start = 12)
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for row in df.index:
    try:
        lat_long = df['coordinates'][row]
        lat = lat_long['latitude']
        long = lat_long['longitude']
        name = df['name'][row]
        rating = df['rating'][row]
        price = df['price'][row]
        details = "{}\nPrice: {} Rating:{}".format(name,str(price),str(rating))
        popup = folium.Popup(details, parse_html=True)
        marker = folium.Marker([lat, long], popup=popup)
        marker.add_to(base_map)
    except:
        print('Hit error on row: {}'.format(row))
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Summary
#
# Nice work! In this lab, you synthesized your skills for the day, making multiple API calls to Yelp in order to paginate through a results set, performing some basic exploratory analysis and then creating a nice map visual to display the results! Well done!
